# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("../Artifacts/prompt_eval_sol_crit_code_check_dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("../Artifacts/prompt_eval_sol_crit_code_check_dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nimport json\n\ndef extract_s3_bucket_names(template_content):\n    # Pattern: S3Bucket followed by one or more alphanumeric characters\n    pattern = r'S3Bucket[A-Za-z0-9]+'\n    matches = re.findall(pattern, template_content)\n    return matches\n\n# If template_content is a string or file path\nif __name__ == \"__main__\":\n    # Example usage\n    template = \"\"\"\n    {\n        \"Resources\": {\n            \"S3BucketData\": {},\n            \"S3BucketLogs123\": {},\n            \"S3Bucket\": {},\n            \"MyS3BucketName\": {},\n            \"S3BucketArchive\": {}\n        }\n    }\n    \"\"\"\n    \n    results = extract_s3_bucket_names(template)\n    print(json.dumps(results, indent=2))\n",
#     "test_case": {
#       "task": "Extract all AWS S3 bucket names from CloudFormation template resource names that follow the pattern 'S3Bucket' followed by alphanumeric characters",
#       "format": "regex",
#       "solution_criteria": "Regex should match valid S3 bucket resource logical IDs in CloudFormation (e.g., 'S3BucketMyData', 'S3BucketLogs') and capture the bucket identifier portion"
#     },
#     "score": 8.0,
#     "reasoning": "The regex pattern itself is correct and will match valid CloudFormation resource logical IDs. However, the solution has a critical flaw: it extracts the full resource name rather than just the identifier portion as specified in the criteria ('capture the bucket identifier portion'). Additionally, operating on raw string content without JSON parsing could produce false positives. For a production solution, parsing the JSON structure and extracting only the suffix after 'S3Bucket' would be more robust and aligned with the stated requirements."
#   },
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::bucket-name\",\n        \"arn:aws:s3:::bucket-name/*\"\n      ]\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create an AWS IAM policy JSON document that grants read-only access to a specific S3 bucket and its objects",
#       "format": "json",
#       "solution_criteria": "Valid JSON with proper IAM policy structure including Effect, Action, Resource, and Principal fields; must use s3:GetObject and s3:ListBucket actions only"
#     },
#     "score": 8.5,
#     "reasoning": "The solution provides a well-structured, valid IAM policy that achieves read-only S3 access. The core functionality is sound with correct Actions and Resources. However, it conflicts with the stated criteria in two ways: the missing Principal field and the inclusion of s3:GetObjectVersion beyond the specified minimal actions. The Principal omission is debatable (identity-based vs resource-based policy context), but the extra action violates the explicit 'only' requirement."
#   },
#   {
#     "output": "\nimport re\n\ndef is_valid_ec2_instance_id(instance_id):\n    pattern = r'^i-[0-9a-f]{17}$'\n    return bool(re.match(pattern, instance_id))\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS EC2 instance ID and returns whether it is a valid instance ID format (e.g., 'i-0123456789abcdef0')",
#       "format": "python",
#       "solution_criteria": "Function should validate the format using string methods or regex; return boolean; handle edge cases like None or empty strings"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly implements the core validation logic using regex, but fails to meet the explicit requirement of handling edge cases like None or empty strings. The function will crash on None input rather than gracefully returning False. A production-ready solution should include type checking and None handling before the regex match."
#   }
# ]
